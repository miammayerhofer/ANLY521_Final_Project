# %%
# Import libraries
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.model_selection import train_test_split
import datasets
import re
import time
import math
import ast

# %%
# Read in raw text data
df = pd.read_csv('../../modified_data/text_and_summaries_filtered.csv')
# Make sure split_cleaned_text column is in the form of true lists not strings of lists
df['split_cleaned_text'] = df['split_cleaned_text'].apply(lambda x: ast.literal_eval(x))
# Print the first few rows
df.head()
# Out:
#   state_name state    bill_id bill_name  keep  \
# 0     Alaska    AK    AK HB27      HB27     1
# 1     Alaska    AK   AK HB105     HB105     1
# 2     Alaska    AK    AK SB96      SB96     1
# 3    Arizona    AZ  AZ SB1028    SB1028     1
# 4    Arizona    AZ  AZ SB1026    SB1026     1
#
#                                        original_text  \
# 0    HB0027a  1  HB 27   New Text Underlined  DEL...
# 1    HB0105a  1  HB 105   New Text Underlined  DE...
# 2    SB0096A  1  SB 96   New Text Underlined  DEL...
# 3       i      Senate Engrossed  adult cabaret pe...
# 4       i      Senate Engrossed  state monies  dr...
#
#                                         cleaned_text  \
# 0  100 AS 14 18 040 is amended by adding a new su...
# 1  100 AS 14 03 016 a is amended to read 6 a A lo...
# 2  100 AS 14 03 016 a is amended to read 6 a A lo...
# 3  100 Title 13 chapter 14 Arizona Revised Statut...
# 4  100 Title 35 chapter 1 article 5 Arizona Revis...
#
#                                   split_cleaned_text  \
# 0  [is amended by adding a new sub, read, d in th...
# 1  [a is amended to read, a a local school boards...
# 2  [a is amended to read, a a local school boards...
# 3  [chapter, arizona revised statutes is, amended...
# 4  [chapter, article, arizona revised, statutes i...
#
#                                              summary  summary_source  \
# 0  The bill amends an existing regulation of scho...     handwritten
# 1  This bill adds to the list of parental rights ...  fast democracy
# 2  This bill adds to the list of parental rights ...  fast democracy
# 3  This bill prohibits a person or business from ...  fast democracy
# 4  This bill prohibits the use of state monies an...  fast democracy
#
#                    category  \
# 0       Schools & Education
# 1       Schools & Education
# 2       Schools & Education
# 3  Free Speech & Expression
# 4  Free Speech & Expression
#
#                                               status  \
# 0                  Referred to committee, 01/19/2023
# 1   First read and referred to committee, 03/08/2023
# 2   First read and referred to committee, 03/08/2023
# 3  Passed Senate; House Committee of the Whole pa...
# 4  Passed Senate; House Committee of the Whole pa...
#
#                                                 link
# 0  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 1  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 2  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 3  https://apps.azleg.gov/BillStatus/BillOverview...
# 4  https://apps.azleg.gov/BillStatus/BillOverview...

# %%
## PREPROCESSING
from transformers import AutoTokenizer
checkpoint = "t5-small"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /Users/miamayerhofer/opt/anaconda3/envs/anly521/lib/python3.11/site-packages/transformers/models/t5/tokenization_t5_fast.py:156: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
def doc_splitting(l, max_token_len = 512):
  '''Function to split the documents dynamically to abide by token limit''' 
  # Initialize sum and list
  total_sum = 0
  idx_list = []
  # Iterate over each item in list
  for i,l in enumerate(l):
    # Check if adding element to sum causes sum to be over limit
    if total_sum + l + 1 > max_token_len: # add 1 because the T-5 model only does an end token
      idx_list.append(i) # add split location to list of indices for splitting
      total_sum = 0 # reset to 0
    total_sum += l
  return idx_list

# %%
# Tokenize
df['token_list'] = df['split_cleaned_text'].apply(lambda x: [tokenizer(i)["input_ids"] for i in x])
# Calculate the length of the token list & split
df['token_list_lens'] = df['token_list'].apply(lambda x: [len(i)-1 for i in x])
df['split_idx_list'] = df['token_list_lens'].apply(lambda x: doc_splitting(x))
df.head()
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (665 > 512). Running this sequence through the model will result in indexing errors
#   state_name state    bill_id bill_name  keep  \
# 0     Alaska    AK    AK HB27      HB27     1
# 1     Alaska    AK   AK HB105     HB105     1
# 2     Alaska    AK    AK SB96      SB96     1
# 3    Arizona    AZ  AZ SB1028    SB1028     1
# 4    Arizona    AZ  AZ SB1026    SB1026     1
#
#                                        original_text  \
# 0    HB0027a  1  HB 27   New Text Underlined  DEL...
# 1    HB0105a  1  HB 105   New Text Underlined  DE...
# 2    SB0096A  1  SB 96   New Text Underlined  DEL...
# 3       i      Senate Engrossed  adult cabaret pe...
# 4       i      Senate Engrossed  state monies  dr...
#
#                                         cleaned_text  \
# 0  100 AS 14 18 040 is amended by adding a new su...
# 1  100 AS 14 03 016 a is amended to read 6 a A lo...
# 2  100 AS 14 03 016 a is amended to read 6 a A lo...
# 3  100 Title 13 chapter 14 Arizona Revised Statut...
# 4  100 Title 35 chapter 1 article 5 Arizona Revis...
#
#                                   split_cleaned_text  \
# 0  [is amended by adding a new sub, read, d in th...
# 1  [a is amended to read, a a local school boards...
# 2  [a is amended to read, a a local school boards...
# 3  [chapter, arizona revised statutes is, amended...
# 4  [chapter, article, arizona revised, statutes i...
#
#                                              summary  summary_source  \
# 0  The bill amends an existing regulation of scho...     handwritten
# 1  This bill adds to the list of parental rights ...  fast democracy
# 2  This bill adds to the list of parental rights ...  fast democracy
# 3  This bill prohibits a person or business from ...  fast democracy
# 4  This bill prohibits the use of state monies an...  fast democracy
#
#                    category  \
# 0       Schools & Education
# 1       Schools & Education
# 2       Schools & Education
# 3  Free Speech & Expression
# 4  Free Speech & Expression
#
#                                               status  \
# 0                  Referred to committee, 01/19/2023
# 1   First read and referred to committee, 03/08/2023
# 2   First read and referred to committee, 03/08/2023
# 3  Passed Senate; House Committee of the Whole pa...
# 4  Passed Senate; House Committee of the Whole pa...
#
#                                                 link  \
# 0  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 1  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 2  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 3  https://apps.azleg.gov/BillStatus/BillOverview...
# 4  https://apps.azleg.gov/BillStatus/BillOverview...
#
#                                           token_list  \
# 0  [[19, 21012, 57, 2651, 3, 9, 126, 769, 1], [60...
# 1  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
# 2  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
# 3  [[5800, 1], [3, 1665, 8892, 9, 15760, 18692, 7...
# 4  [[5800, 1], [1108, 1], [3, 1665, 8892, 9, 1576...
#
#                                      token_list_lens split_idx_list
# 0  [8, 1, 4, 5, 1, 6, 16, 11, 13, 15, 14, 6, 13, ...             []
# 1  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
# 2  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
# 3  [1, 8, 3, 2, 3, 12, 7, 14, 3, 8, 18, 17, 3, 6,...             []
# 4  [1, 1, 5, 6, 2, 4, 15, 18, 12, 11, 15, 18, 12,...             []

# %%
# Check whether it worked
print(df.loc[3, 'split_idx_list'])
print(df.loc[3, 'token_list_lens'])
print(sum(df.loc[3, 'token_list_lens'])) # should be under 512
# Out:
# []
# [1, 8, 3, 2, 3, 12, 7, 14, 3, 8, 18, 17, 3, 6, 11, 2, 7, 11, 14, 8]
# 158

# %%
# Check whether it worked
print(df.loc[3, 'split_idx_list'])
print(sum(df.loc[3, 'token_list_lens'][:80])) # should be under 512
print(sum(df.loc[3, 'token_list_lens'][:80])) # should be under 512
# Out:
# []
# 158
# 158

# %%
def text_split(l, idx):
  '''Function to split a list of text using a list of indices'''
  return [list(i) for i in np.split(np.array(l), idx)]

# %%
# Split text using function
df['split_text_512'] = df.apply(lambda x: text_split(x['split_cleaned_text'], x['split_idx_list']), axis=1)

# %%
# Explode the split text 512 column so each row is one chunk
df = df.explode('split_text_512', ignore_index=True)
df.head()
# Out:
#   state_name state   bill_id bill_name  keep  \
# 0     Alaska    AK   AK HB27      HB27     1
# 1     Alaska    AK  AK HB105     HB105     1
# 2     Alaska    AK  AK HB105     HB105     1
# 3     Alaska    AK   AK SB96      SB96     1
# 4     Alaska    AK   AK SB96      SB96     1
#
#                                        original_text  \
# 0    HB0027a  1  HB 27   New Text Underlined  DEL...
# 1    HB0105a  1  HB 105   New Text Underlined  DE...
# 2    HB0105a  1  HB 105   New Text Underlined  DE...
# 3    SB0096A  1  SB 96   New Text Underlined  DEL...
# 4    SB0096A  1  SB 96   New Text Underlined  DEL...
#
#                                         cleaned_text  \
# 0  100 AS 14 18 040 is amended by adding a new su...
# 1  100 AS 14 03 016 a is amended to read 6 a A lo...
# 2  100 AS 14 03 016 a is amended to read 6 a A lo...
# 3  100 AS 14 03 016 a is amended to read 6 a A lo...
# 4  100 AS 14 03 016 a is amended to read 6 a A lo...
#
#                                   split_cleaned_text  \
# 0  [is amended by adding a new sub, read, d in th...
# 1  [a is amended to read, a a local school boards...
# 2  [a is amended to read, a a local school boards...
# 3  [a is amended to read, a a local school boards...
# 4  [a is amended to read, a a local school boards...
#
#                                              summary  summary_source  \
# 0  The bill amends an existing regulation of scho...     handwritten
# 1  This bill adds to the list of parental rights ...  fast democracy
# 2  This bill adds to the list of parental rights ...  fast democracy
# 3  This bill adds to the list of parental rights ...  fast democracy
# 4  This bill adds to the list of parental rights ...  fast democracy
#
#               category                                            status  \
# 0  Schools & Education                 Referred to committee, 01/19/2023
# 1  Schools & Education  First read and referred to committee, 03/08/2023
# 2  Schools & Education  First read and referred to committee, 03/08/2023
# 3  Schools & Education  First read and referred to committee, 03/08/2023
# 4  Schools & Education  First read and referred to committee, 03/08/2023
#
#                                                 link  \
# 0  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 1  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 2  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 3  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 4  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
#
#                                           token_list  \
# 0  [[19, 21012, 57, 2651, 3, 9, 126, 769, 1], [60...
# 1  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
# 2  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
# 3  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
# 4  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
#
#                                      token_list_lens split_idx_list  \
# 0  [8, 1, 4, 5, 1, 6, 16, 11, 13, 15, 14, 6, 13, ...             []
# 1  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
# 2  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
# 3  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
# 4  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
#
#                                       split_text_512
# 0  [is amended by adding a new sub, read, d in th...
# 1  [a is amended to read, a a local school boards...
# 2  [health from a parent foster parent or guardia...
# 3  [a is amended to read, a a local school boards...
# 4  [health from a parent foster parent or guardia...

# %%
# Create a group by index number to keep track of chunks
df['doc_number'] = df.groupby('bill_id')['split_text_512'].cumcount().add(1)
# Concatenate string list items into single string
df['split_text'] = df['split_text_512'].apply(lambda x: ' '.join(x))
df.head()
# Out:
#   state_name state   bill_id bill_name  keep  \
# 0     Alaska    AK   AK HB27      HB27     1
# 1     Alaska    AK  AK HB105     HB105     1
# 2     Alaska    AK  AK HB105     HB105     1
# 3     Alaska    AK   AK SB96      SB96     1
# 4     Alaska    AK   AK SB96      SB96     1
#
#                                        original_text  \
# 0    HB0027a  1  HB 27   New Text Underlined  DEL...
# 1    HB0105a  1  HB 105   New Text Underlined  DE...
# 2    HB0105a  1  HB 105   New Text Underlined  DE...
# 3    SB0096A  1  SB 96   New Text Underlined  DEL...
# 4    SB0096A  1  SB 96   New Text Underlined  DEL...
#
#                                         cleaned_text  \
# 0  100 AS 14 18 040 is amended by adding a new su...
# 1  100 AS 14 03 016 a is amended to read 6 a A lo...
# 2  100 AS 14 03 016 a is amended to read 6 a A lo...
# 3  100 AS 14 03 016 a is amended to read 6 a A lo...
# 4  100 AS 14 03 016 a is amended to read 6 a A lo...
#
#                                   split_cleaned_text  \
# 0  [is amended by adding a new sub, read, d in th...
# 1  [a is amended to read, a a local school boards...
# 2  [a is amended to read, a a local school boards...
# 3  [a is amended to read, a a local school boards...
# 4  [a is amended to read, a a local school boards...
#
#                                              summary  summary_source  \
# 0  The bill amends an existing regulation of scho...     handwritten
# 1  This bill adds to the list of parental rights ...  fast democracy
# 2  This bill adds to the list of parental rights ...  fast democracy
# 3  This bill adds to the list of parental rights ...  fast democracy
# 4  This bill adds to the list of parental rights ...  fast democracy
#
#               category                                            status  \
# 0  Schools & Education                 Referred to committee, 01/19/2023
# 1  Schools & Education  First read and referred to committee, 03/08/2023
# 2  Schools & Education  First read and referred to committee, 03/08/2023
# 3  Schools & Education  First read and referred to committee, 03/08/2023
# 4  Schools & Education  First read and referred to committee, 03/08/2023
#
#                                                 link  \
# 0  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 1  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 2  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 3  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 4  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
#
#                                           token_list  \
# 0  [[19, 21012, 57, 2651, 3, 9, 126, 769, 1], [60...
# 1  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
# 2  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
# 3  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
# 4  [[3, 9, 19, 21012, 12, 608, 1], [3, 9, 3, 9, 4...
#
#                                      token_list_lens split_idx_list  \
# 0  [8, 1, 4, 5, 1, 6, 16, 11, 13, 15, 14, 6, 13, ...             []
# 1  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
# 2  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
# 3  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
# 4  [6, 14, 12, 9, 17, 2, 12, 8, 1, 13, 15, 1, 11,...           [49]
#
#                                       split_text_512  doc_number  \
# 0  [is amended by adding a new sub, read, d in th...           1
# 1  [a is amended to read, a a local school boards...           1
# 2  [health from a parent foster parent or guardia...           2
# 3  [a is amended to read, a a local school boards...           1
# 4  [health from a parent foster parent or guardia...           2
#
#                                           split_text
# 0  is amended by adding a new sub read d in this ...
# 1  a is amended to read a a local school boards h...
# 2  health from a parent foster parent or guardian...
# 3  a is amended to read a a local school boards h...
# 4  health from a parent foster parent or guardian...

# %%
df.columns
# Out:
# Index(['state_name', 'state', 'bill_id', 'bill_name', 'keep', 'original_text',
#        'cleaned_text', 'split_cleaned_text', 'summary', 'summary_source',
#        'category', 'status', 'link', 'token_list', 'token_list_lens',
#        'split_idx_list', 'split_text_512', 'doc_number', 'split_text'],
#       dtype='object')

# %%
filtered_df = df[["state_name", "state", "bill_id", "bill_name", "doc_number", "split_text", "summary", "summary_source", "category", "status", "link"]]

# %%
filtered_df.head()
# Out:
#   state_name state   bill_id bill_name  doc_number  \
# 0     Alaska    AK   AK HB27      HB27           1
# 1     Alaska    AK  AK HB105     HB105           1
# 2     Alaska    AK  AK HB105     HB105           2
# 3     Alaska    AK   AK SB96      SB96           1
# 4     Alaska    AK   AK SB96      SB96           2
#
#                                           split_text  \
# 0  is amended by adding a new sub read d in this ...
# 1  a is amended to read a a local school boards h...
# 2  health from a parent foster parent or guardian...
# 3  a is amended to read a a local school boards h...
# 4  health from a parent foster parent or guardian...
#
#                                              summary  summary_source  \
# 0  The bill amends an existing regulation of scho...     handwritten
# 1  This bill adds to the list of parental rights ...  fast democracy
# 2  This bill adds to the list of parental rights ...  fast democracy
# 3  This bill adds to the list of parental rights ...  fast democracy
# 4  This bill adds to the list of parental rights ...  fast democracy
#
#               category                                            status  \
# 0  Schools & Education                 Referred to committee, 01/19/2023
# 1  Schools & Education  First read and referred to committee, 03/08/2023
# 2  Schools & Education  First read and referred to committee, 03/08/2023
# 3  Schools & Education  First read and referred to committee, 03/08/2023
# 4  Schools & Education  First read and referred to committee, 03/08/2023
#
#                                                 link
# 0  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 1  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 2  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 3  https://www.akleg.gov/basis/Bill/Detail/33?Roo...
# 4  https://www.akleg.gov/basis/Bill/Detail/33?Roo...

# %%
# Save dataframe
filtered_df.to_csv('../../modified_data/text_and_summaries_filtered_split.csv', index = False)
